# %% [markdown]
# <a href="https://colab.research.google.com/github/marcin119a/PODSTAWY-UCZENIA-MASZYNOWEGO-W-PYTHONIE-/blob/main/UO_Podstawy_uczenia_maszynowego_Zajecia_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 


tips = pd.read_csv('https://raw.githubusercontent.com/marcin119a/PODSTAWY-UCZENIA-MASZYNOWEGO-W-PYTHONIE-/main/tips.csv')

# %% [markdown]
# ### DataFrame

# %%
tips.head(8)
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4
# 5           5       25.29  4.71    Male     No  Sun  Dinner     4
# 6           6        8.77  2.00    Male     No  Sun  Dinner     2
# 7           7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
tips.tail(10)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 234         234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235         235       10.07  1.25    Male     No   Sat  Dinner     2
# 236         236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237         237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238         238       35.83  4.67  Female     No   Sat  Dinner     3
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.shape
# Out:
# (244, 8)

# %%
tip_column = tips['tip']

# %%
tip_column.tail(10)
# Out:
# 234    3.00
# 235    1.25
# 236    1.00
# 237    1.17
# 238    4.67
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, dtype: float64

# %%
tips[['tip', 'total_bill']]
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# ..    ...         ...
# 239  5.92       29.03
# 240  2.00       27.18
# 241  2.00       22.67
# 242  1.75       17.82
# 243  3.00       18.78
#
# [244 rows x 2 columns]

# %%
tip_column.shape
# Out:
# (244,)

# %% [markdown]
# ### I am interested in the tip of the Tips data.

# %%
tip_column.head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
tips[tips['total_bill'] > 20]
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 2             2       21.01  3.50    Male     No  Sun  Dinner     3
# 3             3       23.68  3.31    Male     No  Sun  Dinner     2
# 4             4       24.59  3.61  Female     No  Sun  Dinner     4
# 5             5       25.29  4.71    Male     No  Sun  Dinner     4
# 7             7       26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...         ...   ...     ...    ...  ...     ...   ...
# 237         237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238         238       35.83  4.67  Female     No  Sat  Dinner     3
# 239         239       29.03  5.92    Male     No  Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [97 rows x 8 columns]

# %%
tip_less_20 = tips.loc[tips['tip'] < 2, 'total_bill']
tip_less_20.tail(10)
# Out:
# 215    12.90
# 217    11.59
# 218     7.74
# 222     8.58
# 224    13.42
# 233    10.77
# 235    10.07
# 236    12.60
# 237    32.83
# 242    17.82
# Name: total_bill, dtype: float64

# %% [markdown]
# #### I am interested in the bills less that 20.

# %%
bill_less_20 = tips[tips['total_bill'] < 20]
bill_less_20.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 6           6        8.77  2.00    Male     No  Sun  Dinner     2
# 8           8       15.04  1.96    Male     No  Sun  Dinner     2
# 9           9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# #### I am interested in the bills when size group is equal to 2 or 3.

# %%
size_23 = tips[tips["size"].isin([2, 3])]
size_23.head(20)
# Out:
#     Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0            0       16.99  1.01  Female     No  Sun  Dinner     2
# 1            1       10.34  1.66    Male     No  Sun  Dinner     3
# 2            2       21.01  3.50    Male     No  Sun  Dinner     3
# 3            3       23.68  3.31    Male     No  Sun  Dinner     2
# 6            6        8.77  2.00    Male     No  Sun  Dinner     2
# 8            8       15.04  1.96    Male     No  Sun  Dinner     2
# 9            9       14.78  3.23    Male     No  Sun  Dinner     2
# 10          10       10.27  1.71    Male     No  Sun  Dinner     2
# 12          12       15.42  1.57    Male     No  Sun  Dinner     2
# 14          14       14.83  3.02  Female     No  Sun  Dinner     2
# 15          15       21.58  3.92    Male     No  Sun  Dinner     2
# 16          16       10.33  1.67  Female     No  Sun  Dinner     3
# 17          17       16.29  3.71    Male     No  Sun  Dinner     3
# ...

# %%
subset_frame = tips.iloc[9:25, 2:5]
subset_frame.head(20)
# Out:
#      tip     sex smoker
# 9   3.23    Male     No
# 10  1.71    Male     No
# 11  5.00  Female     No
# 12  1.57    Male     No
# 13  3.00    Male     No
# 14  3.02  Female     No
# 15  3.92    Male     No
# 16  1.67  Female     No
# 17  3.71    Male     No
# 18  3.50  Female     No
# 19  3.35    Male     No
# 20  4.08    Male     No
# 21  2.75  Female     No
# 22  2.23  Female     No
# 23  7.58    Male     No
# 24  3.18    Male     No

# %% [markdown]
# ### I am interested in the tip and total_bill of the Tips data.

# %%
tip_total_bill = tips[["tip", "total_bill"]]
tip_total_bill.head()
# Out:
#     tip  total_bill
# 0  1.01       16.99
# 1  1.66       10.34
# 2  3.50       21.01
# 3  3.31       23.68
# 4  3.61       24.59

# %%
tip_total_bill.shape
# Out:
# (244, 2)

# %%
tip_column
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %% [markdown]
# ### How do I create prlots in pandas?

# %%
tip_column.plot.hist()

# %%
tip_total_bill
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# ..    ...         ...
# 239  5.92       29.03
# 240  2.00       27.18
# 241  2.00       22.67
# 242  1.75       17.82
# 243  3.00       18.78
#
# [244 rows x 2 columns]

# %%
tip_total_bill.plot.scatter(x='total_bill', y='tip')

# %% [markdown]
# ### How to create new columns derived from existing columns?

# %% [markdown]
# #### I want to express the ration tips divided by total_bill in percentage.

# %%
tips['percent_of_tip'] = tips['tip'] / tips['total_bill']

# %%
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size  \
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_of_tip
# 0          0.059447
# 1          0.160542
# 2          0.166587
# 3          0.139780
# 4          0.146808
# ...

# %%
tips['percent_of_tip'].head(20)
# Out:
# 0     0.059447
# 1     0.160542
# 2     0.166587
# 3     0.139780
# 4     0.146808
# 5     0.186240
# 6     0.228050
# 7     0.116071
# 8     0.130319
# 9     0.218539
# 10    0.166504
# 11    0.141804
# 12    0.101816
# 13    0.162778
# 14    0.203641
# 15    0.181650
# 16    0.161665
# 17    0.227747
# 18    0.206246
# 19    0.162228
# Name: percent_of_tip, dtype: float64

# %% [markdown]
# #### I want to express the average bill per person.

# %%
tips['average_bill'] = tips['total_bill'] / tips['size']
tips['average_bill'].head(10)
# Out:
# 0     8.495000
# 1     3.446667
# 2     7.003333
# 3    11.840000
# 4     6.147500
# 5     6.322500
# 6     4.385000
# 7     6.720000
# 8     7.520000
# 9     7.390000
# Name: average_bill, dtype: float64

# %% [markdown]
# ### What is the average bill of the data?

# %% [markdown]
# #### I want to express the average bill per person.

# %%
 tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
tips[['total_bill', 'tip']].mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# dtype: float64

# %% [markdown]
# What is cumsum of the total_bill column?

# %%
tips['total_bill'].cumsum()
# Out:
# 0        16.99
# 1        27.33
# 2        48.34
# 3        72.02
# 4        96.61
#         ...
# 239    4741.32
# 240    4768.50
# 241    4791.17
# 242    4808.99
# 243    4827.77
# Name: total_bill, Length: 244, dtype: float64

# %%
tips['total_bill'].sum()
# Out:
# 4827.77

# %%
tips[['total_bill', 'tip']].median()
# Out:
# total_bill    17.795
# tip            2.900
# dtype: float64

# %%
tips.describe()
# Out:
#        Unnamed: 0  total_bill         tip        size  percent_of_tip
# count  244.000000  244.000000  244.000000  244.000000      244.000000
# mean   121.500000   19.785943    2.998279    2.569672        0.160803
# std     70.580923    8.902412    1.383638    0.951100        0.061072
# min      0.000000    3.070000    1.000000    1.000000        0.035638
# 25%     60.750000   13.347500    2.000000    2.000000        0.129127
# 50%    121.500000   17.795000    2.900000    2.000000        0.154770
# 75%    182.250000   24.127500    3.562500    3.000000        0.191475
# max    243.000000   50.810000   10.000000    6.000000        0.710345

# %% [markdown]
# I am interested in the bills that tip is less that 20 from Dinner.

# %%
result = tips.query("tip < 2 & time == 'Dinner' ")
result.to_csv('tips20_dinner.csv')

# %%
result
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker  day    time  size  \
# 0             0       16.99  1.01  Female     No  Sun  Dinner     2
# 1             1       10.34  1.66    Male     No  Sun  Dinner     3
# 8             8       15.04  1.96    Male     No  Sun  Dinner     2
# 10           10       10.27  1.71    Male     No  Sun  Dinner     2
# 12           12       15.42  1.57    Male     No  Sun  Dinner     2
# 16           16       10.33  1.67  Female     No  Sun  Dinner     3
# 30           30        9.55  1.45    Male     No  Sat  Dinner     2
# 43           43        9.68  1.32    Male     No  Sun  Dinner     2
# 53           53        9.94  1.56    Male     No  Sun  Dinner     2
# 57           57       26.41  1.50  Female     No  Sat  Dinner     2
# 58           58       11.24  1.76    Male    Yes  Sat  Dinner     2
# 62           62       11.02  1.98    Male    Yes  Sat  Dinner     2
# 67           67        3.07  1.00  Female    Yes  Sat  Dinner     1
# ...

# %% [markdown]
# ## Zadanie 1
#
# 1. Wczytaj danę do zmiennej df_income z poniższego kodu.
# 2. Wyświetl, 10 ostatnich i pierwszych wierzy tej ramki.
# 3. Sprawdź, ile ramka ma wierzy i kolumn za pomocą .shape .
# 4. Odfiltruj te kraję, które mają PKB na osobę mniejsze niż 2500.
# 5. Dodaj kolumnę, w której będzie informacja o całkowitym PKB. (Hint: wystarczy wymnożyć PKB na osobę z populacją).
# 6. Policz średnią dla PKB na osobę dla wszystkich krajów za pomocą .mean() .
# 7. Policz medianę dla PKB na osobę i Populacji  za pomocną .median() .
# 8. Ile jest krajów z Północnej Ameryki, które mają poniżej 100 000 populacji?
# 9. Zapisz te kraje do pliku CSV.

# %%
import pandas as pd 

df_income = pd.read_csv('https://raw.githubusercontent.com/marcin119a/PODSTAWY-UCZENIA-MASZYNOWEGO-W-PYTHONIE-/main/income.csv', sep=';')

# %%
df_income[''].value_counts()
# Out:
# Africa           52
# Asia             49
# Europe           41
# North America    26
# Australia        12
# South America    12
# Name: Continent, dtype: int64

# %%
df_income.query('`Population` <= 100000 & Continent == "North America"')
# Out:
#                  Country  GDP per capita  Life expectancy  Population  \
# 82             Greenland           27763             72.1       56114
# 91              Dominica           10503             73.1       73162
# 125  Antigua and Barbuda           21049             76.4       99923
# 146              Bermuda           47081             78.5       65250
#
#          Continent
# 82   North America
# 91   North America
# 125  North America
# 146  North America

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Zadanie 2
#
# 1. Wczytaj ramkę titanic.csv
# 2. Sprawdź ile jest wierszy w tej ramce.
# 3. Policz średnią wieku osób na Tytanicu.
# 4. Narysuj histogram dla wieku osób będącnych na titanicu.
# 5. Jaka jest mediana dla wieku osób będących na titanicu?
# 6. Odfiltruj te osoby, które były w 3 klasie pasażerów, ile jest takich osób?
# 7. Ile osób przetrwało tą tragedię, ile spośród nich było kobietami?
# 8. Ile było kobiet a ile facetów na pokładzie tytanica? Narysuj histogram.
# 9. Ile osób było pełnoletnich, narysuj dla ich wieku histogram?
# 10. Użyj metody .describe(), ile lat ma najstarsza i najmłodsza osoba na titanicu?
